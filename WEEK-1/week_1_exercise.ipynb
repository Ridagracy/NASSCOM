# %% [markdown]
# <a href="https://colab.research.google.com/github/Ridagracy/NASSCOM/blob/main/week_1_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']

LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

raw_sensor_data = []

for i in range(1, 101):
    timestamp_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    device_id = f"DEV{i:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    reading = (timestamp_str, device_id, device_type, location, value)
    raw_sensor_data.append(reading)

print("First 5 Sensor Readings:")
for reading in raw_sensor_data[:5]:
    print(reading)
# Out:
# First 5 Sensor Readings:
# ('2026-07-19 18:08:13', 'DEV001', 'Light_Sensor', 'Lab1', 229.99)
# ('2026-07-19 18:08:13', 'DEV002', 'Light_Sensor', 'OfficeB', 561.39)
# ('2026-07-19 18:08:13', 'DEV003', 'Light_Sensor', 'Lab2', 373.26)
# ('2026-07-19 18:08:13', 'DEV004', 'Pressure_Sensor', 'OfficeB', 1029.75)
# ('2026-07-19 18:08:13', 'DEV005', 'Pressure_Sensor', 'Warehouse', 984.2)

# %%
# Task 1.2: Create a list of temperature readings as dictionaries

temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temp_dict = {
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        }
        temperature_readings.append(temp_dict)

# Display the first 5 temperature readings
print("First 5 Temperature Readings:")
for temp in temperature_readings[:5]:
    print(temp)
# Out:
# First 5 Temperature Readings:
# {'timestamp': '2026-07-19 18:08:13', 'device_id': 'DEV007', 'location': 'Warehouse', 'temperature_celsius': 20.23}
# {'timestamp': '2026-07-19 18:08:13', 'device_id': 'DEV015', 'location': 'OfficeA', 'temperature_celsius': 28.27}
# {'timestamp': '2026-07-19 18:08:13', 'device_id': 'DEV017', 'location': 'OfficeB', 'temperature_celsius': 28.14}
# {'timestamp': '2026-07-19 18:08:13', 'device_id': 'DEV019', 'location': 'OfficeA', 'temperature_celsius': 27.83}
# {'timestamp': '2026-07-19 18:08:13', 'device_id': 'DEV028', 'location': 'OfficeB', 'temperature_celsius': 24.91}

# %%
# Task 1.3: Create a set of unique locations

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print("Unique Locations:")
print(unique_locations)
# Out:
# Unique Locations:
# {'OfficeA', 'OfficeB', 'Lab1', 'Warehouse', 'Lab2'}

# %%
# Task 1.4: Create a dictionary of device statistics

device_stats = {}

# Initialize with large/small values
for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

# Find minimum and maximum values
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    min_value, max_value = device_stats[device_type]

    if value < min_value:
        min_value = value

    if value > max_value:
        max_value = value

    device_stats[device_type] = (min_value, max_value)

# Display the results
print("Device Statistics:")
for device, stats in device_stats.items():
    print(f"{device}: Min = {stats[0]}, Max = {stats[1]}")
# Out:
# Device Statistics:
# Temperature_Sensor: Min = 19.73, Max = 29.44
# Humidity_Sensor: Min = 30.78, Max = 73.91
# Pressure_Sensor: Min = 981.77, Max = 1029.75
# Light_Sensor: Min = 133.42, Max = 988.2

# %%
# Task 1.5.1: List Slicing

# Extract elements from the 10th to the 20th (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

# Display the results
print("10th to 20th readings (inclusive):")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th reading:")
for reading in sliced_readings_2:
    print(reading)
# Out:
# 10th to 20th readings (inclusive):
# ('2026-07-19 18:08:13', 'DEV010', 'Humidity_Sensor', 'OfficeB', 60.4)
# ('2026-07-19 18:08:13', 'DEV011', 'Light_Sensor', 'Warehouse', 536.89)
# ('2026-07-19 18:08:13', 'DEV012', 'Humidity_Sensor', 'Lab2', 68.3)
# ('2026-07-19 18:08:13', 'DEV013', 'Pressure_Sensor', 'Lab2', 999.27)
# ('2026-07-19 18:08:13', 'DEV014', 'Humidity_Sensor', 'Warehouse', 69.55)
# ('2026-07-19 18:08:13', 'DEV015', 'Temperature_Sensor', 'OfficeA', 28.27)
# ('2026-07-19 18:08:13', 'DEV016', 'Pressure_Sensor', 'Lab1', 1024.31)
# ('2026-07-19 18:08:13', 'DEV017', 'Temperature_Sensor', 'OfficeB', 28.14)
# ('2026-07-19 18:08:13', 'DEV018', 'Light_Sensor', 'Warehouse', 739.54)
# ('2026-07-19 18:08:13', 'DEV019', 'Temperature_Sensor', 'OfficeA', 27.83)
# ('2026-07-19 18:08:13', 'DEV020', 'Light_Sensor', 'OfficeA', 209.04)
#
# Every 5th reading:
# ('2026-07-19 18:08:13', 'DEV001', 'Light_Sensor', 'Lab1', 229.99)
# ('2026-07-19 18:08:13', 'DEV006', 'Humidity_Sensor', 'Warehouse', 69.95)
# ('2026-07-19 18:08:13', 'DEV011', 'Light_Sensor', 'Warehouse', 536.89)
# ('2026-07-19 18:08:13', 'DEV016', 'Pressure_Sensor', 'Lab1', 1024.31)
# ('2026-07-19 18:08:13', 'DEV021', 'Light_Sensor', 'Lab1', 655.86)
# ('2026-07-19 18:08:13', 'DEV026', 'Pressure_Sensor', 'Warehouse', 990.1)
# ('2026-07-19 18:08:13', 'DEV031', 'Light_Sensor', 'Lab1', 398.22)
# ('2026-07-19 18:08:13', 'DEV036', 'Temperature_Sensor', 'Lab2', 29.44)
# ('2026-07-19 18:08:13', 'DEV041', 'Pressure_Sensor', 'OfficeA', 982.16)
# ('2026-07-19 18:08:13', 'DEV046', 'Light_Sensor', 'OfficeA', 478.67)
# ('2026-07-19 18:08:13', 'DEV051', 'Temperature_Sensor', 'Lab2', 22.25)
# ('2026-07-19 18:08:13', 'DEV056', 'Humidity_Sensor', 'OfficeA', 62.07)
# ('2026-07-19 18:08:13', 'DEV061', 'Temperature_Sensor', 'OfficeA', 27.48)
# ('2026-07-19 18:08:13', 'DEV066', 'Light_Sensor', 'OfficeA', 280.88)
# ('2026-07-19 18:08:13', 'DEV071', 'Light_Sensor', 'OfficeA', 850.9)
# ('2026-07-19 18:08:13', 'DEV076', 'Humidity_Sensor', 'OfficeA', 68.22)
# ('2026-07-19 18:08:13', 'DEV081', 'Humidity_Sensor', 'Lab1', 49.71)
# ('2026-07-19 18:08:13', 'DEV086', 'Humidity_Sensor', 'Lab1', 47.86)
# ('2026-07-19 18:08:13', 'DEV091', 'Light_Sensor', 'OfficeA', 665.65)
# ('2026-07-19 18:08:13', 'DEV096', 'Light_Sensor', 'Lab1', 925.1)

# %%
# Task 1.5.2: String Slicing

sample_string = "PythonProgrammingIsFun"

# Extract "Programming"
substring_1 = sample_string[6:17]

# Extract "nohtyP" (reverse of "Python")
substring_2 = sample_string[5::-1]

print("Substring 1:", substring_1)
print("Substring 2:", substring_2)
# Out:
# Substring 1: Programming
# Substring 2: nohtyP

# %%
# Task 1.5.3: Mixed Slicing

# Access the device_type of the 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Extract the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

# Display the results
print("5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)
# Out:
# 5th Reading Device Type: Pressure_Sensor
# Device Type Suffix: Sensor

# %%
# --- Task 2: Writing and Using Functions in Python ---

# 2.1 Function to get readings by location
def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result

# %%
# 2.2 Function to calculate average temperature
def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return round(average, 2)

# %%
# 2.3 Function to generate a report line
def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

# %%
# Task 3.1: Create a directory named 'sensor_reports'

import os

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")
# Out:
# Directory 'sensor_reports' created.

# %%
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 0 hours, 0 minutes.

# %%
# Task 3.3: Generate 5 random integers between 100 and 200 (inclusive)

random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("Random Values:", random_values)
# Out:
# Random Values: [165, 191, 133, 148, 143]
